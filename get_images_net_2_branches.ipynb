# %%
import os
import pickle 
import pandas as pd
import numpy as np
from PIL import Image
from shutil import copyfile

# %%
with open('gsa/images_gsa.pickle', 'rb') as f:
    gsa = pickle.load(f)
with open('dermis/image_dermis.pickle', 'rb') as f:
    dermis = pickle.load(f)
with open('dermnet/image_dermnet.pickle', 'rb') as f:
    dermnet = pickle.load(f)
with open('iowa/image_iowa.pickle', 'rb') as f:
    iowa = pickle.load(f)
with open('chicago/image_chicago.pickle', 'rb') as f:
    chicago = pickle.load(f)
with open('atlas_derm/image_atlas.pickle', 'rb') as f:
    atlas_derm = pickle.load(f)
with open('hellenic/image_hellenic.pickle', 'rb') as f:
    hellenic = pickle.load(f)
with open('dermnetnz/dermentnz_images.pickle', 'rb')  as f:
    dermnetnz = pickle.load(f)
with open('ulb/image_ulb.pickle', 'rb') as f:
    ulb = pickle.load(f)

# %%
gsa_d = []
for image in gsa:
    gsa_d.append([image[0], image[2].lower()])
dermis_d = []
for image in dermis:
    if image[-1]:
        dermis_d.append([image[0], image[-1].lower().strip()])
ulb_d = []
for image in ulb:
    ulb_d.append([image[-1], image[0]])

# %%
datasets = [ulb_d, gsa_d, dermis_d, dermnet, iowa, chicago, atlas_derm, hellenic, dermnetnz]

# %%
list_ds = [['atopic dermatitis',
  'lichen simplex chronicus lsc',
  'infantile atopic eczema',
  'atopic dermatitis with cataract',
  'eczema atopic dermatitis',
  'atopic eczema',
  'atopic eczema of the hands',
  'lichen simplex chronicus vidal',
  'eczéma atopique',
  'eczéma atopique du nourrisson',
  "eczéma atopique chez l'enfant",
  'Atopic Dermatitis Adult Phase',
  'Lichen Simplex Chronicus',
  'Atopic Dermatitis Childhood Phase',
  'Atopic Dermatitis Infant phase',
  'Atopic Dermatitis Feet',
  'Atopic Dermatitis Hyperlinear Creases',
  'Atopic Dermatitis',
  'Lichen simplex chronicus',
  'atopic dermatitis',
  'lichen simplex',
  'Atopic dermatitis images',
  'Atopic eczema images',
  'Lichen simplex images'],
 ['acne cystic',
  'acne',
  'acne comedonal',
  'acne keloidalis nuchae',
  'steroid acne',
  'neonatal acne',
  'acne neonatorum',
  'acne fulminans',
  'tropical acne',
  'acne scars',
  'infantile acne',
  'acne inversa',
  'acne cystica',
  'acne conglobata',
  'acne papulopustulosa',
  'acne comedonica',
  'acne fulminans',
  'acné excoriée des jeunes filles',
  'acne vulgaris',
  'acne infantilis',
  'steroid acne',
  'acne, keloidal scar',
  'acne, scars',
  'acne aestivalis',
  'acne varioliformis hebra',
  'acne venenata',
  'oil acne',
  'acné aux corticoïdes',
  'acné excoriée',
  'acné sur anti-egf',
  'acné vulgaire',
  'acné péribuccale',
  'acné chéloïdienne',
  'acné inverséemaladie de verneuil',
  'acné cicatricielle',
  'acné fulminante',
  'acné papulopustuleuse',
  'acné phlegmoneuse',
  'acné microkystique',
  'acné agminata',
  'acné comédonienne',
  'acné conglobata',
  'acrokératose verruciforme',
  'acné, pigmentation post inflammatoire',
  'Acne Cystic',
  'Acne Open Comedo',
  'Acne Pustular',
  'Acne Keloidalis',
  'Acne Closed Comedo',
  'Acne Excoriated',
  'Acne Infantile',
  'Acne Scar',
  'Acne Primary Lesions',
  'Acne Histology',
  'Acne Mechanica',
  'Acne Conglobata',
  'Acne keloidalis Scars',
  'acne',
  'acne_fulminans',
  'acne neonatorum',
  'Acne, Cystic',
  'Acne, inflammatory of the face',
  'Necrotic Acne',
  'Acne infantile',
  'Acne, Comedonal',
  'Acne, inflammatory',
  'Acne, Fulminans',
  'Acne vulgaris',
  'Acne, Atrophic and Hypertrophic scars',
  'Acne - Striae',
  'Acne cheloidalis',
  'Acne, Aestivalis (Mallorca type)',
  'Post-acne, hypertrophic scars',
  'Acne of the back',
  'Acne - Cystic lesions of the thorax',
  'Acne, factitia',
  'Acne and other follicular disorder images',
  'Acne affecting the back images',
  'Acne affecting the face images',
  'Facial acne images'],
 ['psoriasis',
  'psoriasis palmoplantar',
  'psoriasis pustular',
  'psoriasis nails',
  'infantile seborrheic dermatitis',
  'psoriasis guttate',
  'psoriasis inversa',
  'psoriasis erythrodermic',
  'sebopsoriasis',
  'psoriasis rupioid',
  'chronic pustular psoriasis of pregnancy',
  'psoriasis vitiligo',
  'psoriasis linear',
  'psoriatic keratoderma',
  'psoriasis follicular',
  'psoriasis arthropathic',
  'psoriasis vulgaris, chronic stationary type',
  'psoriasis vulgaris, nail changes',
  'psoriasis inversa',
  'pustular psoriasis of the palms and soles',
  'psoriasis vulgaris, guttate type',
  'psoriasis palmoplantaris',
  'psoriasis arthropathica',
  'psoriatic erythroderma',
  'psoriasis érythrodermique',
  'psoriasis en plaques',
  'psoriasis inverse des plis',
  'psoriasis du cuir chevelu',
  'psoriasis pustuleux plantaire',
  'psoriasis pustuleux palmaire',
  'psoriasis palmo-plantaire',
  "psoriasis de l'enfant",
  'psoriasis des ongles',
  'psoriasis de la pulpe des doigts',
  'psoriasis congénital',
  'psoriasis arthropathie psoriasique',
  'psoriasis du visage',
  'psoriasis génital',
  'psoriasis des pieds',
  'psoriasis des mains',
  'psoriasis disséminé',
  'psoriasis des pouces',
  'psoriasis du nourrisson',
  'psoriasis en gouttes',
  'psoriasis inversé',
  'Psoriasis',
  'Psoriasis Chronic Plaque',
  'Psoriasis Palms Soles',
  'Psoriasis Guttate',
  'Psoriasis Scalp',
  'Psoriasis Pustular Generalized',
  'Patch Testing',
  'Psoriasis Inversus',
  'Psoriasis Nails',
  'Psoriasis Erythrodermic',
  'Psoriasis Penis',
  'Psoriasis Histology',
  'Psoriasis Anus',
  'Psoriasis Light Sensative',
  'Psoriasis Treatment',
  'Psoriasis Infants',
  'Psoriasis Digits',
  'Psoriasis HIV',
  'Psoriasis Cellulitis',
  'Psoriasis Vulva',
  'Psoriasis',
  'Psoriasis (1)',
  'Psoriasis (3) of the Legs',
  'Psoriasis (4) of the Scalp',
  'Psoriasis (7), plaque-type',
  'Psoriasis Oil Spot',
  'Psoriasis, plaque type',
  'Psoriatic Arthritis, chronic',
  'psoriasis',
  'psoriasis-pustular psoriasis',
  'psoriasis- nail psoriasis',
  'psoriasis-psoriasis after erysipelas',
  'arthropathic psoriasis',
  'Psoriasis',
  'Plaque psoriasis',
  'Psoriatic nails',
  'Pustular psoriasis',
  'Psoriasis of the Genitalia',
  'Generalized psoriasis',
  'Psoriasis, Keobner phenomenon',
  'Inverse psoriasis',
  'Psoriasis on vitiligo lesion',
  'Psoriasis of the palms and soles (Keratoderma)',
  "Psoriasis, Generalised 'en plaques'",
  'Psoriasis of the face',
  'Psoriatic plantar keratodema',
  'Psoriasis and bullous pemphigoid - Coexistence',
  'Psoriasis modified by topical application of viper venom!',
  'Psoriasis pustular',
  'Psoriasis of the nipple',
  'Guttate psoriasis',
  'Palmoplantar psoriasis images',
  'Genital psoriasis images',
  'Facial psoriasis images',
  'Psoriasis affecting the face images',
  'Chronic plaque psoriasis images',
  'Generalised pustular psoriasis images',
  'Guttate psoriasis images',
  'Nail psoriasis images',
  'Psoriasis of the scalp images'],
 ['rosacea',
  'pityriasis rosea',
  'rhinophyma',
  'pyoderma faciale',
  'steroid induced rosacea',
  'oral papilloma',
  'rosacea',
  'rhinophyma',
  'pyoderma faciale',
  'rosacea, lupoid',
  'rosacea, lupoid',
  'Павел Гришко: акне или розацеа acné rosacée',
  'rhinophyma',
  'acné rosacée granulomateuse',
  'rhinophymaacné rosacée',
  'Rosacea',
  'Pityriasis Rosea',
  'Rosacea Nose',
  'Rosacea Steroid',
  'Rosacea Granulomatous',
  'Otophyma',
  'Rhinophyma',
  'acne rosacea',
  'rinofima',
  'rosacea-granulomatous_rosacea',
  'rosacea-opthalmic rosacea',
  'Rosacea',
  'Rhinophyma',
  'Rosacea images',
  'Rhinophyma images'],
 ['genital warts',
  'verruca vulgaris',
  'verruca plana',
  'papilloma virus',
  'anogenital warts',
  'verruca vulgaris',
  'verrue plane',
  'verrue chez un immuno-déprimé',
  'verrue plantaire',
  'verrue vulgaire',
  'verrue intra-buccale',
  'Genital Warts',
  'Warts Common',
  'Warts Plantar',
  'Warts Flat',
  'Warts Digitate',
  'Warts',
  'Warts Cryotherapy',
  'Warts Periungual',
  'Periungual Warts',
  'Warts Immunocompromised',
  'Warts Oral',
  'Warts Mouth',
  'Warts Treatment',
  'Wart',
  'Verruca',
  'Verruca Plana',
  'Flat warts of the face',
  'Kissing Warts of the Fingers',
  'Wart of the hand',
  'Wart of the Temple',
  'warts vulgaris',
  'warts filiformis',
  'warts plane',
  'warts plantaris',
  'Warts',
  'Plantar warts',
  'Multiple, plane warts',
  'Wart of the Tongue',
  'Wart',
  'Viral warts images',
  'Genital wart images'],
 ['herpes zoster',
  'herpes simplex',
  'varicella',
  'herpetic whitlow',
  'herpes genitalis',
  'herpes labialis',
  'neonatal varicella',
  'genital herpes',
  'herpes zoster opthalmicus',
  'herpes gestationis',
  'herpes zoster',
  'varicella',
  'herpes simplex',
  'herpes gestationis',
  'herpes simplex genitalis',
  'zoster gangraenosus',
  'herpes simplex analis',
  'herpes simplex oralis',
  'herpes simplex labialis',
  'zoster ophthalmicus',
  'zoster mucosae',
  'zoster generalisatus',
  'varicelle',
  'herpès génital',
  'herpès',
  'herpès chronique hiv',
  'varicelle sur coup de soleil',
  'herpès de la fesse',
  'herpès labial',
  'herpès primo-infection herpétique génitale',
  'herpès, panaris herpétique',
  'herpès folliculaire',
  'Herpes Zoster',
  'Herpes Cutaneous',
  'Herpes Type 1 Recurrent',
  'Herpes Type 1 Primary',
  'Herpes Type 2 Primary',
  'Varicella',
  'Herpes Simplex',
  'Herpes Type 2 Recurrent',
  'Herpes Buttocks',
  'Herpes Immunocompromised',
  'Varicella Infection',
  'Herpes Zoster',
  'Varicella Zoster',
  'Herpes Simplex',
  'Herpes Simplex- Congenital',
  'Herpetic Whitlow',
  'Herpes zoster (1)',
  'Herpes zoster (disseminated)',
  'herpes simplex',
  'varicella',
  'herpes zoster',
  'herpetic sycosis',
  'herpes gestationis',
  'herpetic gingivostomatite',
  'herpes zoster-varicella',
  'Herpes Zoster',
  'Herpes Simplex',
  'Genital Herpes',
  'Herpes labialis',
  'Herpes gestationis',
  'Herpes simplex images',
  'Varicella images',
  'Herpes zoster images',
  'Genital herpes images'],
 ['lichen planus',
  'lichen planus actinicus',
  'lichen planus hypertrophic',
  'lichen planus oral',
  'lichen planopilaris',
  'lichen planus annular',
  'annular lichen planus',
  'lichen planus pigmentosus',
  'lichen planus linear',
  'linear lichen planus',
  'lichen planus nails',
  'lichen planus childhood',
  'lichen planus and vitiligo',
  'lichen planus ulcerative',
  'lichen planus',
  'lichen planus of the mucosa',
  'lichen planus of the mucosa, erosive',
  'lichen planus exanthematicus',
  'lichen planus verrucosus',
  'lichen planus annularis',
  'lichen planus of the oral mucosa',
  'lichen planus planopilaris',
  'lichen planus atrophicans',
  'lichen planus pigmentosus',
  'lichen plan',
  'lichen annulaire',
  'lichen plan buccal',
  'lichen plan pilaire',
  'lichen plan des ongles',
  'Lichen Planus',
  'Lichen Planus Oral',
  'Lichen Planus Hypertrophic',
  'Lichen Planus Penis',
  'Lichen Planus Vaginal',
  'Lichen Planus Palm Soles',
  'Lichen Planopilaris',
  'Lichen Planus',
  'Lichen planus pilaris',
  'Lichen planus (1), Oral',
  'lichen planus',
  'lichen planus actinicus',
  'lichen planus follicularis',
  'lichen planus linearis',
  'lichen planus-vesicular',
  'lichen_planus-bullous_lichen_planus',
  'lichen planus annular',
  'lichen planus of the mucosa',
  'lichen planus verrucosus',
  'Lichen planus, annular',
  'Lichen planus of the nails',
  'Lichen planus pigmentosus',
  'Follicular Lichen Planus (Lichen Planopilaris)',
  'Lichen planopilaris of the scalp',
  'Lichen planus',
  'Lichen annular',
  'Lichen planus of the genitocrural region',
  'Lichen planus of the glans penis',
  'Lichen planus of the penis',
  'Genital lichen planus images',
  'Vulval lichen planus images',
  'Lichen planus images',
  'Vulval erosive lichen planus images',
  'Lichen planus nail images'],
 ['vitiligo',
  'vitiligo repigmentation',
  'segmental vitiligo',
  'contact vitiligo',
  'vitiligo',
  'vitiligo',
  'Vitiligo',
  'Vitiligo',
  'vitiligo',
  'Vitiligo',
  'Vitiligo and alopecia areata',
  'Vitiligo images'],
 ['allergic contact dermatitis',
  'lip lickers dermatitis',
  'contact dermatitis allergic',
  'dermatitis artefacta',
  'plant contact dermatitis',
  'phototoxic reaction',
  'chronic actinic dermatitis',
  'contact dermatitis irritant',
  'paederus dermatitis',
  'phototoxic dermatitis',
  'allergic contact dermatitis, acute & chronic',
  'acute irritant contact dermatitis',
  'factitial dermatitis',
  'phytophotodermatitis',
  'dermatitis solaris',
  'hypereosinophilic dermatitis',
  'allergic contact eczema type i',
  'diaper dermatitis',
  'photoallergic contact dermatitis',
  'chronic cumulative irritant contact eczema',
  'phototoxic contact dermatitis',
  'anal dermatitis',
  'berloque dermatitis',
  'contact stomatitis',
  'x-ray ulcer',
  'eczéma allergique de contact',
  'eczéma par irritation primaire',
  'eczéma allergique de contact aux chaussures',
  'eczéma allergique de contact au zovirax',
  'photosensibilisation de contact par parfum',
  'eczéma allergique de contact sur les paupières',
  'eczéma allergique de contact sur henné',
  'eczéma allergique de contact au sparadrap',
  'photosensibilisation',
  'hypersensibilité aux graminées',
  'photosensibilisation médicamenteuse',
  'eczéma allergique de contact à un antimycosique',
  'hypersensibilité alimentaire',
  'eczéma allergique de contact à une lunette de wc',
  'eczéma allergique de contact au nickel',
  'eczéma allergique de contact au stéristrip',
  'eczéma allergique de contact pseudo-lymphomateux',
  'eczéma allergique de contact au parfum',
  'eczéma allergique de contact aux textiles',
  'Allergic Contact Dermatitis',
  'Sun Damaged Skin',
  'Phototoxic Reactions',
  'Shoe Allergy',
  'Factitial Dermatitis',
  'Irritant Contact Dermatitis',
  'Sunburn',
  'Cosmetic Fragrance Allergy',
  'Fiberglass Dermatitis',
  'Contact Dermatitis Leg Ulcers',
  'Diaper Dermatitis',
  'Contact Dermatitis',
  'Phototoxic Dermatitis',
  'Contact dermatitis (Bacitracin)',
  'Contact dermatitis (Nail Adhesive)',
  'Contact dermatitis (Neomycin)',
  'Contact dermatitis (Poison Ivy)',
  'contact dermatitis',
  'factitial dermatitis',
  'diaper dermatitis',
  'Allergic Contact Dermatitis',
  'Photoaging',
  'Dermatitis',
  'Dermatitis from fig-tree',
  'Dermatitis of the eyelids',
  'Soft callus',
  'Photosensitivity reaction due to Flutamide',
  'Irritant contact dermatitis',
  'Dermatitis, Contact, toxic',
  'Sea weed dermatitis',
  'Perforating dermatosis (aquired reactive)',
  'Allergic contact dermatitis',
  'Dermatitis images',
  'Contact allergic dermatitis of the arm and leg images',
  'Contact allergic dermatitis of the face images',
  'Contact allergic dermatitis of the hand images',
  'Contact allergic dermatitis of the torso images',
  'Solar keratosis affecting the face images',
  'Solar keratosis affecting the hand images',
  'Solar keratosis affecting the legs and feet images',
  'Solar keratosis affecting the scalp images',
  'Contact irritant dermatitis images'],
 ['discoid eczema',
  'stasis dermatitis',
  'eczema varicose',
  'eczema discoid',
  'eczema lichenified',
  'dyshidrotic eczema',
  'asteatotic eczema',
  'eczema of nipple and areola',
  'pityriasiform lichenoid eczema',
  'infected eczema',
  'infective eczema',
  'allergic hand eczema',
  'nummular eczema',
  'asteatotic eczema',
  'stasis dermatitis',
  'hyperkeratotic fissured hand and foot eczema',
  'dyshidrotic eczema',
  'eczema (prurigo like)',
  'eczema nails',
  'dyshidrose',
  'eczéma allergique',
  'eczéma séborrhéique',
  'eczéma crevassé',
  'dyshidrose infectée',
  'eczéma nummullaire',
  'eczéma craquelé',
  'Eczema Fingertips',
  'Eczema Hand',
  'Eczema Nummular',
  'Eczema Subacute',
  'Eczema Foot',
  'Eczema Chronic',
  'Eczema Asteatotic',
  'Eczema Trunk Generalized',
  'Eczema',
  'Eczema Leg',
  'Eczema Areola',
  'Eczema Lids',
  'Eczema Acute',
  'Eczema Arms',
  'Eczema Impetiginized',
  'Eczema Face',
  'Eczema Vulva',
  'Eczema Ears',
  'Eczema Histology',
  'Eczema Scrotum',
  'Eczema Hyperkeratotic',
  'Eczema Vaccinatum',
  'Eczema Axillae',
  'Eczema Penis',
  'Eczema, dyshidrotic (1)',
  'eczematid',
  'tylotic dermatitis',
  'eczema microbic',
  'dyshidrotic eczema',
  'stasis eczema',
  'Infected eczema',
  'Eczema',
  'Dyshidrotic eczema',
  'Nummular eczema',
  'Gravitational eczema',
  'Hand eczema',
  'Eczema of the nipple',
  'Discoid eczema images'],
 ['tinea corporis',
  'tinea faciei',
  'tinea cruris',
  'tinea incognito',
  'kerion',
  'tinea capitis',
  'tinea manum',
  'tinea circinata',
  'tinea unguium',
  'tinea versicolor',
  'tinea pedis',
  'tinea nigra',
  'tinea barbae',
  'tinea imbricata',
  'dermatophytosis',
  'lymphoma blastic nk cell type',
  'dermatophytide',
  'tinea cruris tinea manum',
  'mycosis fungoides',
  'onychomycosis',
  'tinea corporis',
  'tinea pedis',
  'tinea faciei',
  'tinea barbae profunda',
  'tinea capitis profunda',
  'tinea capitis superficialis',
  'tinea amiantacea',
  'tinea manus',
  'tinea inguinalis',
  'trichomycosis palmellina',
  'tinea inguinalis',
  'teigne',
  'favus',
  "mycose, teigne d'origine humaine",
  'kérion',
  'tinea cruris',
  'kerion',
  'Trichomycosis',
  'Tinea Tonsurans Adult',
  'Tinea Corporis',
  'Tinea Capitis',
  'Tinea Versicolor',
  'Tinea Faciale',
  'Tinea Pedis',
  'Tinea corporis (2, close-up)',
  'Tinea corporis of the Arm',
  'tinea nigra',
  'tinea corporis',
  'tinea capitis',
  'tinea facei',
  'kerion celsi',
  'tinea pedis',
  'tinea cruris',
  'trichomycosis axillaris',
  'tinea_pedis_by_nigrospora_sp',
  'tinea amiantacea',
  'tinea manuum',
  'lichen spinulosus',
  'trichomycosis pubis',
  'Tinea infection',
  "Tinea pedis (Athlet's foot)",
  'Tinea faciale',
  'Atopic dermatitis',
  'Tinea corporis due to trichophyton',
  'Tinea Incognita',
  'Tinea',
  'Tinea cruris due to E. floccosum',
  'Tinea capitis',
  'Tinea capitis in an adult',
  'Tinea Cruris',
  'Tinea mannum',
  'Tinea infection, multiple lesions',
  'Tinea, multiple lesions',
  'Tinea infection from Tr. verrucosum',
  'Tinea incognita',
  'Atopic dermatitis - Epidermiditis',
  'Tinea incognito',
  'Tinea manuum due to trichophyton',
  'Tinea corporis and onychomycosis due to trichophyton',
  'Tinea pedis',
  'Tinea nigra',
  'Tinea pedis images',
  'Atopic flexural eczema images',
  'Tinea corporis images'],
 ['bullous pemphigoid, pemphigoid gestationis',
  'bullous pemphigoid',
  'pemphigoïde bulleuse',
  'pemphigoïde bulleuse nodulaire',
  'pemphigus paranéoplasique',
  'pemphigus de senear-usher',
  'pemphigoïde bulleuse localisée',
  'Bullous Pemphigoid',
  'Localized pemphigoid',
  'Bullous Pemphigoid',
  'pemphigoid-bullous pemphigoid',
  'Bullous pemphigoid'],
 ['pemphigus vulgaris',
  'pemphigus vegetans',
  'pemphigus',
  'pemphigoid of pregnancy',
  'pemphigus mucosae',
  'pemphigus vulgaris',
  'pemphigus foliaceus',
  'pemphigus seborrhoicus',
  'pemphigus vegetans',
  'pemphigus vulgaire',
  'Pemphigus',
  'Pemphigus Foliaceous',
  'Pemphigus Vulgaris',
  'pemphigus vulgaris',
  'pemphigus foliaceus',
  'pemphigus vegetans',
  'Pemphigus vulgaris',
  'Pemphigus foliaceus',
  'Pemphigus Vulgaris',
  'pemphigus',
  'Pemphigus vulgaris'],
 ['molluscum contagiosum',
  'molluscum contagiosum',
  'molluscum contagiosum',
  'molluscum contagiosumpou du pubis',
  'molluscum pendulum',
  'Molluscum Contagiosum',
  'Molluscum Contagiosum',
  'Molluscum contagiosum (1)',
  'molluscum contagiosum',
  'Mollescum contagiosum',
  'Molluscum contagiosum images'],
 ['urticaria',
  'urticaria pigmentosa',
  'papular urticaria',
  'urticarial vasculitis',
  'pruritic urticarial papules and plaques of pregnancy',
  'cold urticaria',
  'aquagenic urticaria',
  'pruritic urticarial papules and plaques of pregnancy puppp',
  'urticaria pigmentosa',
  'urticaria',
  'urticarial vasculitis',
  'urticaria mechanica',
  'heat urticaria',
  'solar urticaria',
  'urticaria factitia',
  'urticaire',
  'urticaire aigu',
  'urticaire pigmentaire',
  "urticaire séquelles pigmentées d'un urticaire",
  'Urticaria Acute',
  'Pressure Urticaria',
  'Cholinergic Urticaria',
  'Cold Urticaria',
  'Urticaria- Cold Induced',
  'urticaria',
  'urticaria pigmentosa',
  'pruritic urticarial papules and plaques of pregnancy',
  'Urticaria',
  'Urticaria Pigmentosa',
  'Cholinergic urticaria',
  'Polymorphic Eruption of Pregnancy (Pruritic Urticarial Papules',
  'Urticaria images',
  'Urticarial vasculitis images'],
 ['seborrhoeic keratosis',
  'seborrheic keratosis',
  'Seborrheic Keratoses Ruff',
  'Seborrheic Keratosis Irritated',
  'Stasis Dermatitis and Ulcers',
  'Seborrheic Keratosis',
  'Seborrheic keratosis',
  'Seborrehic keratosis of the Upper Chest',
  'keratosis seborrheic',
  'Seborrhoeic keratosis images'],
 ['scabies',
  'scabies crusted',
  'scabetic nodules',
  'bullous scabies',
  'scabies',
  'gale',
  'gale norvégienne',
  'Scabies',
  'Scabies',
  'norwegian scabies',
  'scabies',
  'scabies atypical',
  'scabies-secondary infection',
  'Scabies',
  'Scabies images'],
 ['seborrheic dermatitis',
  'kératose séborrhéique récidivante',
  'Seborrheic Dermatitis',
  'seborrhoeic dermatitis',
  'Seborrheic Dermatitis'],
 ['actinic keratoses',
  'actinic keratosis',
  'kératose actinique',
  'Actinic Keratosis Face',
  'Actinic Keratosis Pigmented',
  'Actinic Keratosis Scalp',
  'Actinic keratosis Arm',
  'Actinic Keratosis Trunk',
  'keratosis solar',
  'Actinic Keratoses',
  'Actinic dermatitis',
  'Solar lentigo images',
  'Actinic keratosis affecting the face images',
  'Actinic keratosis affecting the hand images',
  'Actinic keratosis affecting the legs and feet images',
  'Actinic keratosis affecting the scalp images',
  'Actinic keratosis treated with imiquimod images',
  'Solar keratosis on the nose images'],
 ['basal cell carcinoma',
  'recurrent bcc',
  'pigmented basal cell carcinoma',
  'basal skin cancer, rodent ulcer',
  'pigmented bcc',
  'basal cell carcinoma',
  'solid-cystic basal cell carcinoma',
  'basal cell carcinoma, morpheiform',
  'basal cell carcinoma, ulcerating',
  'pigmented basal cell carcinoma',
  'superficial basal cell carcinoma',
  'metatypic basal cell carcinoma',
  'Basal Cell Carcinoma Lesion',
  'Basal Cell Carcinoma Pigmented',
  'Basal Cell Carcinoma Nose',
  'Basal Cell Carcinoma Superficial',
  'Basal Cell Carcinoma Face',
  'Basal Cell Carcinoma Lid',
  'Basal Cell Carcinoma Ear',
  'Basal Cell Carcinoma Lip',
  'Basal Cell Carcinoma Scalp',
  'Basal Cell Carcinoma Trunk Ext',
  'Basal Cell Carcinoma Histology',
  'Basal Cell Carcinoma Aldara',
  'Basal Cell Carcinoma Sclerosing',
  'Basal Cell Carcinoma Arm',
  'Basal Cell Carcinoma Surgery',
  'Basal Cell Carcinoma Leg',
  'Basal Cell Carcinoma Vulva',
  'Basal Cell Carcinoma',
  'Histology-Nodular Basal Cell Carcinoma (low power)',
  'Recurrent Basal Cell Carcinoma',
  'Histology-Nodular Basal Cell Carcinoma (high power)',
  'Nodular Basal Cell Carcinoma of the Eyelid',
  'Recurrent Basal Cell Carcinoma of the Nose',
  'Rodent Ulcer Basal Cell Carcinoma',
  'Histology-Morpheaform Basal Cell Carcinoma',
  'Pigmented Basal Cell Carcinoma photomicrograph',
  'Morpheaform Basal Cell Carcinoma',
  'Nodular Basal Cell Carcinoma',
  'Pigmented Basal Cell Carcinoma',
  'Superficial Basal Cell Carcinoma',
  'Basal Cell Carcioma of the Cheek',
  'Nodular Basal Cell Carcinoma of the Cheek',
  'Nodulo-ulcerative Basal Cell Carcinoma of the Cheek',
  'Nodular Basal Cell Carcinoma of the Ear',
  'Recurrent and extensive Basal Cell Carcinoma of the Face',
  'Recurrent Basal Cell Carcinoma of the Forehead',
  'Nodular Basal Cell Carcinoma of the Lip',
  'Basal Cell Carcinoma of the Nose',
  'Recurrent Basal Cell Carcinoma of the Nose after Mohs Micrographic Surgery',
  'Recurrent and extensive Basal Cell Carcinoma of the Scalp',
  'Basal Cell Carcinoma of the Upper Lip',
  'Basal Cell Carcinoma with (histologic) features of Trichoepithelioma',
  'Basal Cell Carcinoma with (histologic) features of Trichoepithelioma defect following Mohs Surgery',
  'Basal cell carcinoma, pigmented type (2)',
  'Palmar Pits of Basal Cell Nevoid Syndrome',
  'basal cell carcinoma',
  'nevoid basal cell carcinoma syndrome',
  'Basal Cell Carcinoma',
  'Basal Cell Carcinoma, cystic',
  'Basal Cell Carcinoma, Superficial',
  'Naevoid basal cell carcinoma syndrome',
  'Basal Cell Carcinoma, on Jadasson nevus',
  'Basal Cell Carcinoma, pigmented',
  'Basal Cell Carcinoma, Albinism',
  'Basal Cell Carcinoma, nodular, ulcerated',
  'Nodular BCC images',
  'Nodular basal cell carcinoma images',
  'BCC affecting the face images',
  'BCC affecting the nose images',
  'BCC affecting the trunk images',
  'Basal cell carcinoma affecting the face images',
  'Basal cell carcinoma affecting the nose images',
  'Basal cell carcinoma affecting the trunk images',
  'Basal cell epithelioma affecting the face images',
  'Basal cell epithelioma affecting the nose images',
  'Basal cell epithelioma affecting the trunk images',
  'Basalioma affecting the face images',
  'Basalioma affecting the nose images',
  'Basalioma affecting the trunk images',
  'BCC affecting the eyelid images',
  'Basal cell carcinoma affecting the eyelid images',
  'Basal cell epithelioma affecting the eyelid images',
  'Basalioma affecting the eyelid images',
  'BCC affecting the ear images',
  'Basal cell carcinoma affecting the ear images',
  'Basal cell epithelioma affecting the ear images',
  'Basalioma affecting the ear images']]

# %%
disease_images = {}
for i in range(1, 21):
    disease_images[i] = []
image_dis = {}
for i in range(len(list_ds)):
    for d in list_ds[i]:
        for dataset in datasets:
            for image in dataset:
                if image[1].lower().strip() == d.lower().strip():
                    disease_images[i + 1].append(image[0])

# %%
list_ms = [['hyperpigmentation',
  'patch',
  'hypopigmentation',
  'purpura',
  'macule brown',
  'telangiectasia',
  'macule red',
  'macule white',
  'macules',
  'macule black',
  'macula / patch',
  'erythema',
  'squame, lésion érythémato-squameuse',
  'macule, érythème',
  'macule, macule pigmentée',
  'purpura',
  'squame, lésion érythémato-squameusevésicule, vésicule par spongiose',
  'macule, macule dépigmentée',
  'livédo',
  'multiples lésions pigmentées',
  'pustulemacule, érythème',
  'macule'],
 ['granulome'],
 ['nodule',
  'nodule,purple',
  'nodule pink',
  'nodule,skin coloured',
  'nodule,black',
  'nodule,yellow',
  'node',
  'tumor',
  'tumeur, tumeur maligne',
  'tumeur, tumeur bénigne',
  'tumeur',
  'tumeur, carcinome spinocellulaire',
  'tumeur, mélanome',
  'nodule'],
 ['plaque',
  'papules,red',
  'papules,skin coloured',
  'papules',
  'papules,brown',
  'papules,yellow',
  'papules,black',
  'papules white',
  'comedone',
  'papule',
  'plaque',
  'papulo-vesicle',
  'papule, papule cellulaire',
  'papule',
  'lésion papulo-squameuse',
  'papule, papulo-pustule',
  'papule, papule oedémateuse',
  'bullepapule, papule oedémateuseulcération',
  'papule, papule nécrosante',
  'macule, érythèmepapule, papule oedémateuse'],
 ['wheal', 'wheal', 'macule, érythèmepapule, papule oedémateuse'],
 ['vesicles',
  'vesiculobullous',
  'vesicle',
  'papulo-vesicle',
  'vésicule, vésicule par spongiose',
  'papule, papule cellulaire',
  'vésicule',
  'squame, lésion érythémato-squameusevésicule, vésicule par spongiose',
  'vésicule, vésicule par nécrose cellulaire',
  'vésicule, vésicule par spongiosesquame, lésion érythémato-squameuse'],
 ['blisters',
  'vesiculobullous',
  'bulla',
  'bulle, bulle dermo-épidermique',
  'bulle',
  'bullepapule, papule oedémateuseulcération',
  'bulle, bulle sous-cornée',
  'bulle, bulle sous-cornéeulcération'],
 ['pustules',
  'abscess',
  'cyst',
  'pustule',
  'papule, papulo-pustule',
  'pustule',
  'pustule, pustule folliculaire',
  'pustulemacule, érythème',
  'papuleulcération, chancre syphilitique'],
 ['lésion pigmentée'],
 [],
 ['erosions', 'erosion'],
 ['ulcer',
  'ulcus',
  'ulcération',
  'ulcération, chancre syphilitique',
  'papuleulcération, chancre syphilitique',
  'bulle, bulle sous-cornéeulcération',
  'lésion ulcérée'],
 ['red,scaly',
  'scales',
  'desquamation',
  'crusted squames',
  'squame, lésion érythémato-squameuse',
  'lésion papulo-squameuse',
  'squame, lésion érythémato-squameusevésicule, vésicule par spongiose',
  'squame'],
 ['crusts', 'crust', 'crusted squames'],
 ['scar', 'scar'],
 [],
 ['excoriation', 'excoriation', 'lésion excoriée'],
 ['keratoderma',
  'hyperkeratosis',
  'keratosis',
  'hyperkératose',
  'hyperkératosesquame, lésion érythémato-squameuse',
  'hypertrophiehyperkératose'],
 ['lichenification', 'lichenification'],
 [],
 ['sclerosis', 'sclerosis', 'sclérose'],
 [],
 ['atrophy', 'atrophy', 'atrophie', 'atrophie, cicatrice']]

# %%
with open('ulb/image_ulb.pickle', 'rb') as f:
    ulb = pickle.load(f)
with open('gsa/images_gsa.pickle', 'rb') as f:
    gsa = pickle.load(f)
with open('dermis/image_dermis.pickle', 'rb') as f:
    dermis = pickle.load(f)
ulb_m = []
for image in ulb:
    ulb_m.append([image[2].strip().lower(), image[-1]])
gsa_m = []
for image in gsa:
    gsa_m.append([image[1].strip().lower(), image[0]])
dermis_m = []
for image in dermis:
    dermis_m.append([image[4], image[0]])

# %%
image_morph = {}
datasets = [ulb_m, gsa_m, dermis_m]
ms = {}
for i in range(1, 9):
    ms[i] = {}
    for j in range(3):
        ms[i][j] = 0
for i in range(8):
    for m in all_ms[i]:
        for d in datasets:
            for image in d:
                if m in image[0]:
                    ms[i + 1][datasets.index(d)] += 1
                    if image[1] in image_morph:
                        image_morph[image[1]].append(i + 1)
                    else:
                        image_morph[image[1]] = [i + 1]

# %%
for k, v in image_morph.items():
    image_morph[k] = list(set(v))

# %%
file_index = 0
labels_d = []
labels_m = []
for k, v in disease_images.items():
    for filename in v:
        if (file_index + 1) % 1000 == 0:
            print(file_index + 1)
        try:
            img = Image.open(filename) 
            img.verify() 
        except (IOError, SyntaxError) as e:
            print('Bad file')
        else:
            copyfile(filename, f'net_dis_morph/{file_index}.jpg')
            if filename in image_morph.keys():
                ms = image_morph[filename]
            else:
                ms = []
            labels_morphology = np.zeros(8)
            for l in ms:
                labels_morphology[l - 1] = 1
            labels_d.append(k - 1)
            labels_m.append(labels_morphology)
            file_index += 1

# %%
with open("net_2_branches_diseases.pickle", 'wb') as f:
    pickle.dump(labels_d, f)
with open('net_2_branches_morphology.pickle', 'wb') as f:
    pickle.dump(labels_m, f)
